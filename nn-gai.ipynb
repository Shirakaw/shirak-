# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. 
from scipy import optimize as opt
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('train_estimates.csv')
train_data.head()
# Out:
#    carid  tradeTime  brand  serial  model  mileage  color  cityId  carCode  \
# 0      1  2021/6/28      1       1      1     4.01      1       1        1
# 1      2  2021/6/25      2       2      2     8.60      1       2        1
# 2      5  2021/6/19      5       5      5    15.56      1       2        3
# 3      6  2021/6/29      6       6      6     6.04      1       3        1
# 4      7  2021/6/30      7       7      7     5.70      4       1        2
#
#    transferCount  ...  anonymousFeature7 anonymousFeature8 anonymousFeature9  \
# 0              0  ...                  0                 1                 5
# 1              0  ...                  0                 2                 4
# 2              0  ...                  0                 0                 0
# 3              3  ...          2018/8/18                 2                 5
# 4              2  ...          2020/9/20                 1                 5
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   carid               35000 non-null  int64
#  1   tradeTime           35000 non-null  object
#  2   brand               35000 non-null  int64
#  3   serial              35000 non-null  int64
#  4   model               35000 non-null  int64
#  5   mileage             35000 non-null  float64
#  6   color               35000 non-null  int64
#  7   cityId              35000 non-null  int64
#  8   carCode             35000 non-null  int64
#  9   transferCount       35000 non-null  int64
#  10  seatings            35000 non-null  int64
#  11  registerDate        35000 non-null  object
#  12  licenseDate         35000 non-null  object
#  13  country             35000 non-null  int64
#  14  maketype            35000 non-null  int64
# ...

# %%
from sklearn.model_selection import train_test_split
X = train_data.drop(['carid', 'price'], axis=1)
y = train_data['carid']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=456)

# %%
#搭建线性模型
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
naive_model = LinearRegression()
naive_model.fit(X_train[['brand','serial','model','mileage','color','cityId','carCode','transferCount','seatings','country','maketype','modelyear','displacement','gearbox','oiltype','newprice','anonymousFeature1','anonymousFeature2','anonymousFeature3','anonymousFeature4','anonymousFeature5','anonymousFeature6','anonymousFeature8','anonymousFeature9','anonymousFeature10','anonymousFeature13','anonymousFeature14']], y_train);
y_pred_naive = naive_model.predict(X_test[['brand','serial','model','mileage','color','cityId','carCode','transferCount','seatings','country','maketype','modelyear','displacement','gearbox','oiltype','newprice','anonymousFeature1','anonymousFeature2','anonymousFeature3','anonymousFeature4','anonymousFeature5','anonymousFeature6','anonymousFeature8','anonymousFeature9','anonymousFeature10','anonymousFeature13','anonymousFeature14']])

# %%
mean_squared_error(y_test, y_pred_naive)
# Out:
# 288506119.90228593

# %%
mean_absolute_error(y_test, y_pred_naive)
# Out:
# 13192.190025528267

# %%
sns.pairplot(train_data[['brand','serial','model','mileage','color','cityId','carCode','transferCount','seatings','country','maketype','modelyear','displacement','gearbox','oiltype','newprice','anonymousFeature1','anonymousFeature2','anonymousFeature3','anonymousFeature4','anonymousFeature5','anonymousFeature6','anonymousFeature8','anonymousFeature9','anonymousFeature10','anonymousFeature13','anonymousFeature14', 'price']].sample(100)); 
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
def create_one_hot_preprocessor():
    return ColumnTransformer([
        ('one_hot_encoder', OneHotEncoder(sparse=False, handle_unknown='ignore'), ['tradeTime', 'registerDate',' licenseDate','anonymousFeature7','anonymousFeature11','anonymousFeature12','anonymousFeature15']),
        ('standard_scaler', StandardScaler(), ['brand','serial','model','mileage','color','cityId','carCode','transferCount','seatings','country','maketype','modelyear','displacement','gearbox','oiltype','newprice','anonymousFeature1','anonymousFeature2','anonymousFeature3','anonymousFeature4','anonymousFeature5','anonymousFeature6','anonymousFeature8','anonymousFeature9','anonymousFeature10','anonymousFeature13','anonymousFeature14'])]
    )
